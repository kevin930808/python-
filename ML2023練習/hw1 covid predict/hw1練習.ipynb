# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
x_train= pd.read_csv('./covid.train2023.csv')
y_train = x_train['tested_positive'].values
x_train = x_train.drop(['id','tested_positive'],axis=1).values

print(x_train.shape,y_train.shape)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(32,activation='sigmoid',input_dim=(87)))
model.add(tf.keras.layers.Dense(16,activation='relu'))
model.add(tf.keras.layers.Dense(8,activation='relu'))
model.add(tf.keras.layers.Dense(4,activation='relu'))
model.add(tf.keras.layers.Dense(1,activation='linear'))
model.compile(optimizer='adam',loss='mse',metrics=['accuracy'])
model.fit(x_train,y_train,batch_size=50,validation_split=0.2,epochs=500,shuffle=True)

model.save('HW1.h5')
# Out:
# (3009, 87) (3009,)
# Epoch 1/500
# 49/49 [==============================] - 0s 3ms/step - loss: 316.9698 - accuracy: 0.0000e+00 - val_loss: 610.3054 - val_accuracy: 0.0000e+00
# Epoch 2/500
# 49/49 [==============================] - 0s 1ms/step - loss: 263.9736 - accuracy: 0.0000e+00 - val_loss: 493.5623 - val_accuracy: 0.0000e+00
# Epoch 3/500
# 49/49 [==============================] - 0s 1ms/step - loss: 166.0260 - accuracy: 0.0000e+00 - val_loss: 294.4308 - val_accuracy: 0.0000e+00
# Epoch 4/500
# 49/49 [==============================] - 0s 1ms/step - loss: 89.6261 - accuracy: 0.0000e+00 - val_loss: 184.1626 - val_accuracy: 0.0000e+00
# Epoch 5/500
# 49/49 [==============================] - 0s 1ms/step - loss: 75.3508 - accuracy: 0.0000e+00 - val_loss: 168.5215 - val_accuracy: 0.0000e+00
# Epoch 6/500
# 49/49 [==============================] - 0s 1ms/step - loss: 73.9682 - accuracy: 0.0000e+00 - val_loss: 171.0069 - val_accuracy: 0.0000e+00
# Epoch 7/500
# ...

# %%
import matplotlib.pyplot as plt
x_test=pd.read_csv('covid.test2023.csv')
x_test = x_test.drop(['id',],axis=1).values
y_test = model.predict(x_test)
print(y_test.shape)
plt.plot(y_test)
# Out:
# 32/32 [==============================] - 0s 613us/step
# (997, 1)
